# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.86 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 39.7/112.6 GB disk)

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("ultralytics/brain-tumor")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /root/.cache/kagglehub/datasets/ultralytics/brain-tumor/versions/2

# %%
# !mkdir datasets
# Out:
# mkdir: cannot create directory ‘datasets’: File exists

# %%
import shutil
import os

# Define source and destination directories
src_dir = "/root/.cache/kagglehub/datasets/ultralytics/brain-tumor/versions/2"
dst_dir = "/content/datasets"  # Change to your desired path

# Ensure destination exists
os.makedirs(dst_dir, exist_ok=True)

# Move files
for file_name in os.listdir(src_dir):
    shutil.move(os.path.join(src_dir, file_name), dst_dir)

print("Files moved successfully!")
# Out:
# Files moved successfully!

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo11m.pt")

# Train the model
results = model.train(data="brain-tumor.yaml", epochs=10, imgsz=640, device=0, batch=16,
    patience=15 # Early stopping if no improvement
                      )
# Out:
# Ultralytics 8.3.86 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
results = model.val(
    data="brain-tumor.yaml",
    imgsz=640,
    batch=32,
    conf=0.001,
    iou=0.7,
    device=0
)
# Out:
# Ultralytics 8.3.86 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11m summary (fused): 125 layers, 20,031,574 parameters, 0 gradients, 67.7 GFLOPs
# val: Scanning /content/datasets/brain-tumor/valid/labels.cache... 223 images, 0 backgrounds, 0 corrupt: 100%|██████████| 223/223 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:08<00:00,  1.16s/it]
#                    all        223        241      0.451      0.847      0.496      0.374
#               negative        142        154      0.581      0.831      0.588      0.441
#               positive         81         87       0.32      0.862      0.404      0.308
# Speed: 3.3ms preprocess, 25.6ms inference, 0.0ms loss, 0.9ms postprocess per image
# Results saved to runs/detect/train92

# %%
results = model.predict(
    source="/content/datasets/brain-tumor/valid/images/val_1 (1).jpg",
    conf=0.1,
    imgsz=1280,
    device=0,
    save=True  # Saves to runs/detect/predict/
)
# Out:
# image 1/1 /content/datasets/brain-tumor/valid/images/val_1 (1).jpg: 1280x1280 2 negatives, 1 positive, 114.2ms
# Speed: 16.9ms preprocess, 114.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
# Results saved to runs/detect/train93

# %%
# Install the required package (Supervision)
# !pip install supervision

# Import necessary libraries
import supervision as sv
import cv2
import random
import numpy as np

# List all image paths from your dataset
image_paths = sv.list_files_with_extensions(
    directory="/content/datasets/brain-tumor/valid/images",
    extensions=['png', 'jpg', 'jpeg']
)

# Choose a random image from the dataset
image_path = random.choice(image_paths)
image = cv2.imread(str(image_path))

# Make predictions using the model
results = model.predict(image, conf=0.10)[0]

# Convert the results into a Detections object
detections = sv.Detections.from_ultralytics(results)

# Check if there are any detections and keep only the highest confidence one
if len(detections) > 0:
    # Find the index of the detection with the highest confidence score
    highest_conf_index = detections.confidence.argmax()

    # Get the class id, confidence, and bounding box for the top detection
    top_confidence = detections.confidence[highest_conf_index]
    top_class_id = detections.class_id[highest_conf_index]
    top_bbox = detections.xyxy[highest_conf_index]

    # Convert confidence to percentage
    confidence_percentage = f"{top_confidence * 100:.2f}%"

    # Keep only the highest confidence detection
    detections = sv.Detections(
        xyxy=np.array([top_bbox]),  # 2D array for bounding box
        confidence=np.array([top_confidence]),  # 1D array for confidence
        class_id=np.array([top_class_id])  # 1D array for class_id
    )

    # Annotate the image with the top detection
    box_annotator = sv.BoundingBoxAnnotator()
    label_annotator = sv.LabelAnnotator(text_color=sv.Color.BLACK)

    # Create a label with class name and confidence percentage
    class_name = model.names[top_class_id]  # Get class name from model
    label = f"{class_name} {confidence_percentage}"

    # Annotate with both bounding box and label
    annotated_image = box_annotator.annotate(scene=image.copy(), detections=detections)
    annotated_image = label_annotator.annotate(scene=annotated_image, detections=detections, labels=[label])

    # Plot the annotated image
    sv.plot_image(annotated_image)
else:
    print("No detections found.")
# Out:
# ...
#
# 0: 640x640 1 negative, 2 positives, 21.1ms
# Speed: 6.1ms preprocess, 21.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# SupervisionWarnings: BoundingBoxAnnotator is deprecated: `BoundingBoxAnnotator` is deprecated and has been renamed to `BoxAnnotator`. `BoundingBoxAnnotator` will be removed in supervision-0.26.0.

# %%
# Install the required package (Supervision)
# !pip install supervision

# Import necessary libraries
import supervision as sv
import cv2
import numpy as np

# Load a single image (replace with your image path or URL)
image_path = "/content/runs/detect/predict/brain-tumor-sample.jpg"  # Example path
image = cv2.imread(image_path)

# Make predictions using the model
results = model.predict(image, conf=0.10)[0]  # You can adjust the confidence threshold (conf)

# Convert the results into a Detections object
detections = sv.Detections.from_ultralytics(results)

# Check if there are any detections and keep only the highest confidence one
if len(detections) > 0:
    # Find the index of the detection with the highest confidence score
    highest_conf_index = detections.confidence.argmax()

    # Get the class id, confidence, and bounding box for the top detection
    top_confidence = detections.confidence[highest_conf_index]
    top_class_id = detections.class_id[highest_conf_index]
    top_bbox = detections.xyxy[highest_conf_index]

    # Convert confidence to percentage
    confidence_percentage = f"{top_confidence * 100:.2f}%"

    # Keep only the highest confidence detection
    detections = sv.Detections(
        xyxy=np.array([top_bbox]),  # 2D array for bounding box
        confidence=np.array([top_confidence]),  # 1D array for confidence
        class_id=np.array([top_class_id])  # 1D array for class_id
    )

    # Annotate the image with the top detection
    box_annotator = sv.BoundingBoxAnnotator()
    label_annotator = sv.LabelAnnotator(text_color=sv.Color.BLACK)

    # Create a label with class name and confidence percentage
    class_name = model.names[top_class_id]  # Get class name from model
    label = f"{class_name} {confidence_percentage}"

    # Annotate with both bounding box and label
    annotated_image = box_annotator.annotate(scene=image.copy(), detections=detections)
    annotated_image = label_annotator.annotate(scene=annotated_image, detections=detections, labels=[label])

    # Plot the annotated image
    sv.plot_image(annotated_image)
else:
    print("No detections found.")
# Out:
# ...
#
# 0: 640x640 1 positive, 36.9ms
# Speed: 3.3ms preprocess, 36.9ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
# SupervisionWarnings: BoundingBoxAnnotator is deprecated: `BoundingBoxAnnotator` is deprecated and has been renamed to `BoxAnnotator`. `BoundingBoxAnnotator` will be removed in supervision-0.26.0.

# %%
model.save("brain-tumor-detector.keras")

# %%
model.save("brain-tumorh5.h5")

# %%
from google.colab import files
files.download('brain-tumorh5.h5')

# %%
model.save("brainv1.tf")

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.18.0
